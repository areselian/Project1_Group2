# %%
import gzip
import csv
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
# %matplotlib inline
from datetime import date
import datetime
import calendar
#import holidays
from pprint import pprint
#import calmap
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
NYC_holiday_avg_price = pd.DataFrame({'Holiday Name': ['New Years Day', 'Washingtons Birthday', 'Martin Luther King Jr Day', 
                                                   'Memorial Day', 'Independence Day', 'Labor Day', 'Columbus Day','Veterans Day','Veternas Day (Observed)','Thanksgiving','Christmas Day'],
                                 'Average Price': [142.3,130.67,142.29,135.16,137.88,141.27,140.85,140.23,140.19,140.83,140.31]})



NYC_holiday_avg_price
# Out:
#                  Holiday Name  Average Price
# 0               New Years Day         142.30
# 1        Washingtons Birthday         130.67
# 2   Martin Luther King Jr Day         142.29
# 3                Memorial Day         135.16
# 4            Independence Day         137.88
# 5                   Labor Day         141.27
# 6                Columbus Day         140.85
# 7                Veterans Day         140.23
# 8     Veternas Day (Observed)         140.19
# 9                Thanksgiving         140.83
# 10              Christmas Day         140.31

# %%
NYC_holiday_avg_price.dtypes
# Out:
# Holiday Name      object
# Average Price    float64
# dtype: object

# %%
### holiday_avg_price.plot(figsize=(15,4))
# holiday_avg_price.plot(subplots=True, figsize=(15,6))
#holiday_avg_price.plot(y=["Average Price"], figsize=(15,4))
NYC_holiday_avg_price.plot(x="Holiday Name",y="Average Price",color='dodgerblue', 
                       marker='o', rot=20,figsize=(15,7),linestyle='dashed', linewidth=4, markersize=12)

plt.title("Breakdown of Rental Prices by National holidays in NYC", fontsize=14, fontweight='bold')

plt.text(0.3,142,'$142.30',fontsize=13)
plt.text(1.2,131,'$130.67',fontsize=13)
plt.text(2.1,142,'$142.3',fontsize=13)
plt.text(3.1,135,'$135.16',fontsize=13)
plt.text(4.1,137,'$137.87',fontsize=13)
plt.text(5.1,142,'$141.27',fontsize=13)
plt.text(6.1,141,'$140.85',fontsize=13)
plt.text(7.1,141,'$140.22',fontsize=13)
plt.text(7.6,139,'$140.18',fontsize=13)
plt.text(8.9,140,'$140.82',fontsize=13)
plt.text(9.5,140,'$140.30',fontsize=13)

plt.show()

plt.savefig("Breakdown of Rental Prices by National holidays in NYC.png")

# %%
SF_holiday_avg_price = pd.DataFrame({'Holiday Name': ['New Years Day', 'Washingtons Birthday', 'Martin Luther King Jr Day', 
                                                   'Memorial Day', 'Independence Day', 'Labor Day', 'Columbus Day','Veterans Day','Thanksgiving','Christmas Day'],
                                 'Average Price': [175.43,166.47,164.61,171.62,174.64,173.74,174.29,173.77,174.57,174.16]})



SF_holiday_avg_price
# Out:
#                 Holiday Name  Average Price
# 0              New Years Day         175.43
# 1       Washingtons Birthday         166.47
# 2  Martin Luther King Jr Day         164.61
# 3               Memorial Day         171.62
# 4           Independence Day         174.64
# 5                  Labor Day         173.74
# 6               Columbus Day         174.29
# 7               Veterans Day         173.77
# 8               Thanksgiving         174.57
# 9              Christmas Day         174.16

# %%
NYC_holiday_avg_price.plot(x="Holiday Name",y="Average Price",color='dodgerblue', 
                       marker='o', rot=20,figsize=(15,7),linestyle='dashed', linewidth=4, markersize=12)

plt.title("Breakdown of Rental Prices by National holidays in NYC", fontsize=14, fontweight='bold')

plt.text(0.3,142,'$142.30',fontsize=13)
plt.text(1.2,131,'$130.67',fontsize=13)
plt.text(2.1,142,'$142.3',fontsize=13)
plt.text(3.1,135,'$135.16',fontsize=13)
plt.text(4.1,137,'$137.87',fontsize=13)
plt.text(5.1,142,'$141.27',fontsize=13)
plt.text(6.1,141,'$140.85',fontsize=13)
plt.text(7.1,141,'$140.22',fontsize=13)
plt.text(7.6,139,'$140.18',fontsize=13)
plt.text(8.9,140,'$140.82',fontsize=13)
plt.text(9.5,140,'$140.30',fontsize=13)

plt.show()

plt.savefig("Breakdown of Rental Prices by National holidays in NYC.png")

# %%
SF_holiday_avg_price.plot(x="Holiday Name",y="Average Price", color='green', 
                       marker='o', rot=20,figsize=(15,7),linestyle='dashed', linewidth=4, markersize=12)

plt.title("Breakdown of Rental Prices by National holidays in SF", fontsize=14, fontweight='bold')

plt.text(0.3,174,'$175.43',fontsize=13)
plt.text(1,166.2,'$166.47',fontsize=13)
plt.text(2.1,164,'$164.61',fontsize=13)
plt.text(3.1,171,'$171.62',fontsize=13)
plt.text(4.1,173.3,'$174.64',fontsize=13)

plt.text(5.1,173,'$173.74',fontsize=13)
plt.text(6.1,174.4,'$174.29',fontsize=13)
plt.text(7,173,'$173.77',fontsize=13)
plt.text(7.9,174,'$174.57',fontsize=13)
plt.text(8.5,173.6,'$174.16',fontsize=13)

plt.savefig("Breakdown of Rental Prices by National holidays in SF.png")
